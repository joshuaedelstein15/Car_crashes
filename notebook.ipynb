# %%
import pandas as pd

# %%
df=pd.read_csv('data/Traffic_Crashes_-_Crashes.csv')
df.head()
# Out:
#                                      CRASH_RECORD_ID RD_NO CRASH_DATE_EST_I  \
# 0  24987175dace867b431edb6469ebe31c9d4c72e28d2721...   NaN              NaN
# 1  a97167d0efcf4f64e11ed8ce422255ec760235fd7e928c...   NaN              NaN
# 2  0d935dc768fcd11621a69f0cf5b4c7285713739858282e...   NaN              NaN
# 3  387401055a6a7b96dcde1bbd3a7d405606294a217b1cda...   NaN              NaN
# 4  4ff9efe34b9f76675709c5bdf0ccad4f016f98880ad119...   NaN              NaN
#
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  04/19/2023 01:30:00 AM                  15            NO CONTROLS
# 1  04/18/2023 11:43:00 PM                  30            NO CONTROLS
# 2  04/18/2023 10:00:00 PM                  10            NO CONTROLS
# 3  04/18/2023 09:28:00 PM                  30            NO CONTROLS
# 4  04/18/2023 08:44:00 PM                  30            NO CONTROLS
#
#   DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# ...
